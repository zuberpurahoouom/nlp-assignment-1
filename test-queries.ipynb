# %% [markdown]
# # Retrieval using first 3 queries from sampled_queries.tsv

# %%
import pandas as pd
sampled_queries = pd.read_csv('sampled_queries_1k.tsv', sep='\t', header=0, names=['qid', 'query'], dtype={'qid': str, 'query': str})
test_queries = sampled_queries.head(1)
test_queries
# Out:
#       qid                              query
# 0  507646  symptoms of flu a & b in children

# %%
collection_df = pd.read_csv("common_dataset_80k.tsv", sep="\t", header=None, names=["pid", "text"], dtype={"pid": str, "text": str})
collection_df.head()
# Out:
#     pid                                               text
# 0   448  A postal code (also known locally in various E...
# 1   466  Therefore, all pathologists must have complete...
# 2   646  Obesity is a complex disorder involving an exc...
# 3  1212  Which president appointed FBI Director James C...
# 4  1213  Comey was confirmed by the Senate on July 29, ...

# %%
qrels_dev = pd.read_csv('qrels.dev.tsv', sep='\t', header=None, names=['qid', '_', 'pid', 'label'], dtype={'qid': str, 'pid': str, 'label': int})
query_ground_truth = qrels_dev[qrels_dev['qid'].isin(test_queries['qid'])]
query_ground_truth = query_ground_truth.merge(collection_df, on='pid', how='left')
# To print the full text without truncation in Jupyter, use pandas display options:
pd.set_option('display.max_colwidth', None)
print(query_ground_truth.head()['text'].iloc[0])
# Out:
# A: Symptoms of influenza in children include a high-grade fever, extreme fatigue, a headache, body aches and a dry, hacking cough, according to WebMD. Children with influenza may also experience a sore throat, belly pain, vomiting, and chills and shakes.

# %%
def format_topN_results(topN_results, test_queries, collection_df):
    rows = []
    for qid, results in topN_results.items():
        query = test_queries.loc[test_queries['qid'] == qid, 'query'].values[0]
        for pid, score in results:
            passage = collection_df.loc[collection_df['pid'] == pid, 'text'].values[0]
            rows.append({'query': query, 'pid': pid, 'passage': passage, 'score': score})
    return pd.DataFrame(rows)

# %% [markdown]
# ### Test retrieval with TF-IDF

# %%
import joblib
from tf_idf_utils import retrieve_topN_for_queries

vectorizer = joblib.load('tfidf_vectorizer.joblib')
doc_matrix = joblib.load('tfidf_doc_matrix.joblib')

topN_results = retrieve_topN_for_queries(vectorizer, doc_matrix, collection_df['pid'], test_queries, topN=10)

pd.set_option('display.max_colwidth', None)
retrieval_df = format_topN_results(topN_results, test_queries, collection_df)
retrieval_df.head()
# Out:
# Retrieving: 100%|██████████| 1/1 [00:00<00:00, 37.69it/s]
#                                query      pid  \
# 0  symptoms of flu a & b in children   822848
# 1  symptoms of flu a & b in children  7071178
# 2  symptoms of flu a & b in children  7201019
# 3  symptoms of flu a & b in children  1580421
# 4  symptoms of flu a & b in children   196474
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                       passage  \
# ...

# %% [markdown]
# ## Test retrieval with BM25

# %%
from whoosh import index
from whoosh.qparser import QueryParser, OrGroup
from whoosh.scoring import BM25F
from tqdm.auto import tqdm
IDX_DIR = "indexes/whoosh"
K1, B = 1.2, 0.75

topN_results = {}

ix = index.open_dir(IDX_DIR)
with ix.searcher(weighting=BM25F(k1=K1, b=B)) as searcher:
    qp = QueryParser("text", schema=ix.schema, group=OrGroup)
    it = test_queries[["qid","query"]].itertuples(index=False, name=None)

    for qid, query in it:
        q = qp.parse(query)
        results = searcher.search(q, limit=10)
        rows = [(r['pid'], r.score) for r in results]
        topN_results[str(qid)] = rows

pd.set_option('display.max_colwidth', None)
retrieval_df = format_topN_results(topN_results, test_queries, collection_df)
retrieval_df.head()
# Out:
#                                query      pid  \
# 0  symptoms of flu a & b in children  1580421
# 1  symptoms of flu a & b in children  7087923
# 2  symptoms of flu a & b in children  7988185
# 3  symptoms of flu a & b in children  7492976
# 4  symptoms of flu a & b in children    35887
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              passage  \
# ...

# %% [markdown]
# ## Test retrieval with DPR

# %%
import numpy as np
embedding_filename = f"passage_embeddings_80k.npy"

# Load later
passage_embeddings = np.load(embedding_filename)
print(passage_embeddings.shape)
# Out:
# (80000, 768)

# %%
import faiss
dim = passage_embeddings.shape[1]  # typically 768 for DPR
faiss.normalize_L2(passage_embeddings)  # normalize for cosine similarity
index = faiss.IndexFlatIP(dim)
index.add(passage_embeddings)

print("Number of vectors in FAISS:", index.ntotal)
# Out:
# Number of vectors in FAISS: 80000

# %%
import numpy as np
import torch
import faiss
from tqdm import tqdm
from transformers import DPRQuestionEncoder, DPRQuestionEncoderTokenizer

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

question_encoder = DPRQuestionEncoder.from_pretrained("./dpr_question_encoder").to(DEVICE)
question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained("./dpr_question_encoder")

qids = test_queries['qid'].tolist()
queries_list = test_queries['query'].tolist()

for qid, q in tqdm(zip(qids, queries_list), total=len(queries_list), desc="Retrieving"):
    inputs = question_tokenizer(q, return_tensors="pt", padding=True, truncation=True).to(DEVICE)
    with torch.no_grad():
        q_emb = question_encoder(**inputs).pooler_output
    D, I = index.search(q_emb.detach().cpu().numpy(), 10)

    rows = [(collection_df.iloc[i]['pid'], float(d)) for i, d in zip(I[0], D[0])]
    topN_results[str(qid)] = rows

pd.set_option('display.max_colwidth', None)
retrieval_df = format_topN_results(topN_results, test_queries, collection_df)
retrieval_df.head()
# Out:
# ...
# Retrieving: 100%|██████████| 1/1 [00:00<00:00,  2.66it/s]
#                                query      pid  \
# 0  symptoms of flu a & b in children  7548862
# 1  symptoms of flu a & b in children  7619619
# 2  symptoms of flu a & b in children  7828612
# 3  symptoms of flu a & b in children  7480406
# 4  symptoms of flu a & b in children   109900
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               passage  \
# ...

# %% [markdown]
# ## Test re-ranking with Cross Encoder

# %%
from sentence_transformers import CrossEncoder

cross_model = CrossEncoder("./cross-encoder-model")

pairs = list(zip(retrieval_df["query"], retrieval_df["passage"]))

cross_scores = cross_model.predict(pairs, show_progress_bar=True)
retrieval_df["cross_score"] = cross_scores
retrieval_df = retrieval_df.sort_values(by=["cross_score"], ascending=[False])
pd.set_option('display.max_colwidth', None)
retrieval_df.head(10)
# Out:
# ...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
#                                query      pid  \
# 0  symptoms of flu a & b in children  7548862
# 5  symptoms of flu a & b in children  7590755
# 4  symptoms of flu a & b in children   109900
# 2  symptoms of flu a & b in children  7828612
# 7  symptoms of flu a & b in children  7480405
# 6  symptoms of flu a & b in children  7649123
# 3  symptoms of flu a & b in children  7480406
# 9  symptoms of flu a & b in children  7661062
# 8  symptoms of flu a & b in children   964216
# 1  symptoms of flu a & b in children  7619619
#
# ...

# %% [markdown]
# ### Find a query where DPR's top result is incorrect but Cross Encoder corrects it
# This cell scans a subset of queries to identify a case where:
# - DPR top-1 passage is NOT relevant (not in qrels), but
# - After re-ranking the same DPR candidate set with the Cross Encoder, the new top-1 passage IS relevant.

# %%
import pandas as pd
import numpy as np
import torch, faiss
from transformers import DPRQuestionEncoder, DPRQuestionEncoderTokenizer
from sentence_transformers import CrossEncoder
from tqdm.auto import tqdm

# Parameters
MAX_QUERIES = 50          # how many queries to scan from the sample
CANDIDATE_K = 30          # how many DPR candidates to retrieve per query before re-ranking

sampled_queries = pd.read_csv('sampled_queries_1k.tsv', sep='\t', header=0,
                                  names=['qid','query'], dtype={'qid':str,'query':str})  # shuffle
scan_queries = sampled_queries.sample(MAX_QUERIES)

collection_df = pd.read_csv('common_dataset_80k.tsv', sep='\t', header=None,
                                names=['pid','text'], dtype={'pid':str,'text':str})

# Load qrels (dev) for relevance checking
qrels_dev = pd.read_csv('qrels.dev.tsv', sep='\t', header=None,
                        names=['qid','_','pid','label'], dtype={'qid':str,'pid':str,'label':int})
relevant_map = qrels_dev[qrels_dev.label>0].groupby('qid')['pid'].apply(set).to_dict()

passage_embeddings = np.load('passage_embeddings_80k.npy')
emb_norm = passage_embeddings.copy()
faiss.normalize_L2(emb_norm)
index = faiss.IndexFlatIP(emb_norm.shape[1])
index.add(emb_norm)

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
if 'question_encoder' not in globals():
    question_encoder = DPRQuestionEncoder.from_pretrained('./dpr_question_encoder').to(DEVICE)
    question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained('./dpr_question_encoder')
if 'cross_model' not in globals():
    cross_model = CrossEncoder('./cross-encoder-model', device=DEVICE)

found_case = None
analysis_rows = []

for row in tqdm(scan_queries.itertuples(index=False), total=len(scan_queries), desc='Scanning'):
    qid, query = row.qid, row.query
    rel_pids = relevant_map.get(qid, set())
    if not rel_pids:
        continue  # skip queries with no relevance judgments

    # DPR retrieval
    inputs = question_tokenizer(query, return_tensors='pt', padding=True, truncation=True).to(DEVICE)
    with torch.no_grad():
        q_emb = question_encoder(**inputs).pooler_output
    D, I = index.search(q_emb.detach().cpu().numpy(), CANDIDATE_K)
    cand_indices = I[0]
    cand_scores = D[0]
    cand_pids = [collection_df.iloc[i]['pid'] for i in cand_indices]

    # Check DPR top-1 relevance
    dpr_top_pid = cand_pids[0]
    dpr_top_relevant = dpr_top_pid in rel_pids

    # Prepare pairs for Cross Encoder re-ranking
    passages = [collection_df.iloc[i]['text'] for i in cand_indices]
    pairs = [(query, p) for p in passages]
    ce_scores = cross_model.predict(pairs, show_progress_bar=False)

    # Build ranking by CE
    ce_rank = sorted(zip(cand_pids, passages, ce_scores), key=lambda x: x[2], reverse=True)
    ce_top_pid = ce_rank[0][0]
    ce_top_relevant = ce_top_pid in rel_pids

    # Store limited analysis info (first few for review)
    analysis_rows.append({
        'qid': qid,
        'query': query,
        'dpr_top_pid': dpr_top_pid,
        'dpr_top_is_rel': dpr_top_relevant,
        'ce_top_pid': ce_top_pid,
        'ce_top_is_rel': ce_top_relevant
    })

    # Condition: DPR wrong (non-relevant) AND CE correct (relevant)
    if (not dpr_top_relevant) and ce_top_relevant:
        found_case = {
            'qid': qid,
            'query': query,
            'dpr_top_pid': dpr_top_pid,
            'dpr_top_passage': passages[0],
            'ce_top_pid': ce_top_pid,
            'ce_top_passage': next(p for pid,p,s in ce_rank if pid==ce_top_pid),
            'ce_gain_positions': next(i for i,(pid,p,s) in enumerate(ce_rank) if pid in rel_pids)
        }
        break

if found_case:
    print('Found corrective case:')
    print(f"QID: {found_case['qid']}")
    print(f"Query: {found_case['query']}")
    print('\nDPR Top-1 (Non-relevant):')
    print(f"PID: {found_case['dpr_top_pid']}")
    print(found_case['dpr_top_passage'])
    print('\nCross Encoder New Top-1 (Relevant):')
    print(f"PID: {found_case['ce_top_pid']}")
    print(found_case['ce_top_passage'])
    print(f"\nRelevant passage appeared at CE rank position: {found_case['ce_gain_positions']+1}")
else:
    print('No corrective case found within the scanned queries. Consider increasing MAX_QUERIES or CANDIDATE_K.')

pd.DataFrame(analysis_rows).head(10)
# Out:
# Scanning:   0%|          | 0/50 [00:02<?, ?it/s]
# Found corrective case:
# QID: 775797
# Query: what is needed for a passport
#
# DPR Top-1 (Non-relevant):
# PID: 556571
# If applying for the first time for the passport, the applicant is required to pay a passport application (processing) fee of $75 for those ages 16 years and older and $60 for those 15 years or younger, as well as an execution/acceptance fee of $30. Applying for the passport card costs $10 for children and $20 for adults.
#
# Cross Encoder New Top-1 (Relevant):
# PID: 4408659
# Proof of Identification Required: When you apply for a US passport in person, you will need to present at least one acceptable form of identification, including: 1  Previously issued, undamaged US passport. 2  Valid Driver's License. 3  Naturalization Certificate. 4  Current government ID (city, state or federal).
#
# Relevant passage appeared at CE rank position: 1
#       qid                          query dpr_top_pid  dpr_top_is_rel  \
# ...

# %%
# Timing retrieval latency (encode + top-10 search) for multiple models on a single query
# NOTE:
#  - For neural models (DPR, MiniLM) we include query encoding + ANN search.
#  - For sparse models (TF-IDF, BM25) we include parsing + scoring.
#  - Index / embedding loading is NOT included in timings (done before the timer) because that is usually
#    an offline or one-time startup cost. Adjust if you need cold-start timings.
#  - MiniLM passage embeddings must be precomputed and saved as 'minilm_embeddings_80k.npy'.
#    If unavailable, MiniLM timing will be skipped.

import time
import numpy as np
import pandas as pd
import torch, faiss
from pathlib import Path

results_timing = []

# Select the single query
query_row = test_queries.iloc[0]
query_text = query_row['query']
print(f"Query used for timing: {query_text!r}")

############################
# TF-IDF (vectorizer/doc_matrix assumed loaded earlier)
############################
try:
    from scipy import sparse
    assert 'vectorizer' in globals() and 'doc_matrix' in globals()
    start = time.perf_counter()
    q_vec = vectorizer.transform([query_text])  # shape (1, V)
    scores = doc_matrix @ q_vec.T               # shape (N, 1)
    scores = scores.toarray().ravel()
    # Top-10 indices
    if scores.shape[0] > 10:
        top_idx = np.argpartition(-scores, 10)[:10]
        top_idx = top_idx[np.argsort(-scores[top_idx])]
    else:
        top_idx = np.argsort(-scores)
    tfidf_top10 = [(collection_df.iloc[i]['pid'], float(scores[i])) for i in top_idx]
    elapsed = time.perf_counter() - start
    results_timing.append({'model': 'TF-IDF', 'time_seconds': elapsed, 'notes': 'Includes query vectorization + sparse matmul'})
except Exception as e:
    results_timing.append({'model': 'TF-IDF', 'time_seconds': None, 'notes': f'Skipped: {e}'})

############################
# BM25 (Whoosh)
############################
try:
    from whoosh import index as _w_index
    from whoosh.qparser import QueryParser, OrGroup
    from whoosh.scoring import BM25F
    IDX_DIR = 'indexes/whoosh'
    K1, B = 1.2, 0.75
    ix = _w_index.open_dir(IDX_DIR)
    qp = QueryParser('text', schema=ix.schema, group=OrGroup)
    with ix.searcher(weighting=BM25F(k1=K1, b=B)) as searcher:
        start = time.perf_counter()
        q = qp.parse(query_text)
        hits = searcher.search(q, limit=10)
        bm25_top10 = [(h['pid'], h.score) for h in hits]
        elapsed = time.perf_counter() - start
    results_timing.append({'model': 'BM25', 'time_seconds': elapsed, 'notes': 'Includes parse + scoring'})
except Exception as e:
    results_timing.append({'model': 'BM25', 'time_seconds': None, 'notes': f'Skipped: {e}'})

############################
# DPR (dense) - needs question_encoder and passage_embeddings file
############################
try:
    if 'question_encoder' not in globals() or 'question_tokenizer' not in globals():
        from transformers import DPRQuestionEncoder, DPRQuestionEncoderTokenizer
        DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        question_encoder = DPRQuestionEncoder.from_pretrained('./dpr_question_encoder').to(DEVICE)
        question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained('./dpr_question_encoder')
    else:
        DEVICE = next(question_encoder.parameters()).device

    # Build (or reuse) FAISS index in-memory (not timed)
    if 'dpr_index' not in globals():
        pe = np.load('passage_embeddings_80k.npy')
        pe_norm = pe.copy()
        faiss.normalize_L2(pe_norm)
        dpr_index = faiss.IndexFlatIP(pe_norm.shape[1])
        dpr_index.add(pe_norm)

    start = time.perf_counter()
    inputs = question_tokenizer(query_text, return_tensors='pt', padding=True, truncation=True).to(DEVICE)
    with torch.no_grad():
        q_emb = question_encoder(**inputs).pooler_output  # (1, d)
    q_np = q_emb.detach().cpu().numpy()
    faiss.normalize_L2(q_np)
    D, I = dpr_index.search(q_np, 10)
    dpr_top10 = [(collection_df.iloc[i]['pid'], float(s)) for i, s in zip(I[0], D[0])]
    elapsed = time.perf_counter() - start
    results_timing.append({'model': 'DPR', 'time_seconds': elapsed, 'notes': 'Includes encoding + FAISS IP search'})
except Exception as e:
    results_timing.append({'model': 'DPR', 'time_seconds': None, 'notes': f'Skipped: {e}'})

############################
# MiniLM (SentenceTransformer) - requires precomputed passage embeddings
############################
try:
    minilm_emb_path = Path('minilm_embeddings_80k.npy')
    if not minilm_emb_path.exists():
        raise FileNotFoundError('minilm_embeddings_80k.npy not found (precompute to enable timing).')

    if 'minilm_index' not in globals():
        from sentence_transformers import SentenceTransformer
        DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        minilm_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device=DEVICE)
        minilm_passage_embs = np.load(str(minilm_emb_path))
        # Assume they are not normalized yet
        emb_copy = minilm_passage_embs.copy()
        faiss.normalize_L2(emb_copy)
        minilm_index = faiss.IndexFlatIP(emb_copy.shape[1])
        minilm_index.add(emb_copy)
    if 'minilm_model' not in globals():
        from sentence_transformers import SentenceTransformer
        minilm_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device=DEVICE)

    start = time.perf_counter()
    q_emb = minilm_model.encode([query_text], convert_to_numpy=True, normalize_embeddings=True)
    D, I = minilm_index.search(q_emb, 10)
    minilm_top10 = [(collection_df.iloc[i]['pid'], float(s)) for i, s in zip(I[0], D[0])]
    elapsed = time.perf_counter() - start
    results_timing.append({'model': 'MiniLM', 'time_seconds': elapsed, 'notes': 'Includes encoding + FAISS IP search'})
except Exception as e:
    results_timing.append({'model': 'MiniLM', 'time_seconds': None, 'notes': f'Skipped: {e}'})

# Summary table
latency_df = pd.DataFrame(results_timing).sort_values('model')
print('\nRetrieval latency (single query, top-10):')
print(latency_df)

latency_df
